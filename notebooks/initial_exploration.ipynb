# %% [markdown]
# # Lichess PGN Data Exploration
#
# Goal: Understand the structure and field coverage of the PGN database to verify that the questions I want to ask are answerable by the data.
#
# First, set the path to data:

# %%
PGN_PATH = "../data/raw/lichess_db_standard_rated_2026-02.pgn"

# %% [markdown]
# Next, see what the data format looks like:

# %%
with open(PGN_PATH, encoding="utf-8", errors="replace") as f:
    for i, line in enumerate(f):
        print(line, end="")
        if i >= 30:
            break
# Out:
# [Event "Rated Bullet game"]
# [Site "https://lichess.org/AJrdLVya"]
# [Date "2026.02.01"]
# [Round "-"]
# [White "Orangutanagram"]
# [Black "bachess_2024"]
# [Result "1-0"]
# [UTCDate "2026.02.01"]
# [UTCTime "00:00:33"]
# [WhiteElo "1696"]
# [BlackElo "1617"]
# [WhiteRatingDiff "+4"]
# [BlackRatingDiff "-4"]
# [ECO "B12"]
# [Opening "Caro-Kann Defense: Advance Variation, Short Variation"]
# [TimeControl "60+0"]
# [Termination "Time forfeit"]
#
# ...

# %% [markdown]
# The data exists in [Tag "Value"] format.
